# %%
import pandas as pd

# %%
pd=pd.read_csv("cricinfo.csv")
# pd.set_options()

# %%
pd
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7   626   6
# ...

# %%
pd["country"]=pd["Player"].str.split(pat="(").str[1]
pd["country"]=pd["country"].str.split(pat=")").str[0]
pd["Player"]=pd["Player"].str.split(pat="(").str[0]
pd["start_year"]=pd["Span"].str.split(pat="-").str[0].astype(int)
pd["end_year"]=pd["Span"].str.split(pat="-").str[1].astype(int)
pd.rename(columns={"Span":"Duration","Mat":"Matches","BF":"Balls_Faced","HS":"High_score","SR":"Strike_rate"},inplace=True)
pd["Duration"]=pd["end_year"]-pd["start_year"]
pd["High_score"]=pd["High_score"].str.split(pat="*").str[0].astype(int)
pd["Balls_Faced"]=pd["Balls_Faced"].str.split(pat="+").str[0]
pd["Balls_Faced"]=pd["Balls_Faced"].replace("-",0)
pd["Balls_Faced"]=pd["Balls_Faced"].astype(int)
pd["Strike_rate"]=pd["Strike_rate"].replace("-",0)
pd["Strike_rate"]=pd["Strike_rate"].astype(float)
pd["0"]=pd["0"].replace("-",0)
pd["0"]=pd["0"].astype(int)

# %%
pd.to_csv("newcricinfo.csv",index=False)
